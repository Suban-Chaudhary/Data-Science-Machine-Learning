# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib qt
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips.describe
# Out:
# <bound method NDFrame.describe of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

objects = ("Python","C++","Java","Perl","Scala","Lisp")
y_pos = np.arange(len(objects))
performance = [10,3,3,2,3,1]

plt.bar(y_pos, performance, align = 'center', alpha = 0.9)
plt.xticks(y_pos, objects)
plt.ylabel('Usage')
plt.xlabel('Programming languages')
plt.title("Programming languages usgae")
plt.show()

# %%
sns.barplot(x = 'day', y = 'tip', data = tips)
plt.show()

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.barplot(x='day', y='tip', data= tips, hue= 'sex', palette = 'hls')
plt.show()

# %%
sns.barplot(x = 'day', y= 'total_bill', data = tips, order = ['Sun', 'Sat', "Fri", "Thur"], palette = 'winter')
plt.show()

# %%
sns.barplot(x = 'day', y = 'total_bill', data = tips, capsize = 1, palette = 'autumn')
plt.show()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips.total_bill)
plt.show()

# %%
from scipy import stats
sns.distplot(tips.total_bill, rug = True, norm_hist = True, kde = False, fit = stats.gamma)
plt.show()

# %%
x = np.random.normal(0,1, size = 30)
bandwidth= 1.06 * x.std() * x.size ** (-1/5.)
support = np.linspace(-4,4,200)

kernels = []
for x_i in x:
    
    kernel = stats.norm(x_i, bandwidth).pdf(support)
    kernels.append(kernel)
    plt.plot(support, kernel)
sns.rugplot(x, color = '.2', linewidth = 3)
plt.show()

# %%
from scipy import integrate

# %%
density = np.sum(kernels, axis = 0)
density /= integrate.trapz(density, support)
plt.plot(support , density)
plt.show()

# %%
sns.boxplot(tips['total_bill'])
plt.show()

# %%
sns.boxplot(x = 'day', y = 'total_bill', hue = 'sex', data = tips, palette = 'husl')
plt.show()

# %%
data = pd.read_csv('loan.csv')

# %%
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162               360
# 1             4583             1508.0  128.000000               360
# 2             3000                0.0   66.000000               360
# 3             2583             2358.0  120.000000               360
# 4             6000                0.0  141.000000               360
#
#    Credit_History Property_Area Loan_Status
# 0               1         Urban           Y
# 1               1         Rural           N
# ...

# %%
data.boxplot(column = 'ApplicantIncome')
plt.show()

# %%
data.boxplot(column = 'ApplicantIncome', by = 'Education')
plt.show()

# %%
sns.boxplot(x = 'Education', y = 'ApplicantIncome', data = data)
plt.show()

# %%
sns.boxplot(x = 'Self_Employed', y = 'ApplicantIncome',data = data)
plt.show()

# %%
sns.boxplot(x = 'Education', y = 'LoanAmount', hue = 'Self_Employed', data = data)
plt.show()

# %%
data.boxplot(column = 'LoanAmount', by = ['Education' , 'Self_Employed'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
sns.boxplot(x='day', y='total_bill',  data=tips, palette = 'husl')
plt.show()
sns.swarmplot(x='day', y='total_bill', data=tips)   # data pt. for each interval
plt.show()

# %%
sns.boxplot(x='day', y='total_bill',  data=tips, palette = 'husl')
plt.show()
sns.swarmplot(x='day', y='total_bill', data=tips, color = 'red')   # data pt. for each interval
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x = 'Dependents', hue = 'Gender', data = data, palette='cubehelix_r')
plt.show()

# %%
sns.stripplot(x = tips['tip'],color = 'green')
plt.show()

# %%
sns.stripplot(x='day', y='total_bill', data= tips)
plt.show()

# %%
sns.stripplot(x='day', y='total_bill', data= tips, jitter=0.5)
plt.show()

# %%
sns.stripplot(x = 'day', y = 'total_bill', data = tips, jitter = 0.3, linewidth = 1.2)
plt.show()

# %%
sns.stripplot(x='day', y='total_bill', data= tips, hue='sex',palette='husl', jitter=True, dodge = True)
plt.show()

# %%
sns.stripplot(x='day', y='total_bill', data= tips, hue='sex',palette='husl', jitter=True)
plt.show()

# %%
sns.stripplot(x = 'sex', y = 'tip', data = tips, palette = 'winter_r', marker = '^', jitter = True)

# %%
sns.stripplot(x = 'sex', y = 'tip', hue = 'smoker', data = tips, palette = 'winter_r', marker = 'D', jitter = True, edgecolor = 'grey', size = 15, alpha = 0.3)
plt.show()

# %%
sns.stripplot(x = 'tip', y = 'day', data = tips, jitter = True, orient = 'h', palette = 'winter',color = 1)
plt.show()
sns.boxplot(x = 'tip', y = 'day', data = tips)
plt.show()

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.pairplot(iris)
plt.show()

# %%
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.pairplot(tips)
plt.show()

# %%
sns.pairplot(iris, hue = 'species')
plt.show()

# %%
sns.pairplot(iris, hue = 'species', palette = 'husl', markers = ['D','o','^'])
plt.show()

# %%
sns.pairplot(iris, hue = 'species', vars = ['sepal_length','sepal_width'])
plt.show()

# %%
sns.pairplot(tips, vars=['total_bill','tip'])
plt.show()

# %%
sns.pairplot(tips, diag_kind = 'kde')
plt.show()

# %%
sns.pairplot(tips, diag_kind = 'kde', palette = 'autumn',hue ='smoker')
plt.show()

# %%
sns.pairplot(tips, kind = 'reg')
plt.show()

# %%
sns.pairplot(iris, hue='species',palette='husl',diag_kind='kde',kind='reg')
plt.show()

# %%
x = sns.PairGrid(iris)
x = x.map(plt.scatter)
plt.show()

# %%
y = sns.PairGrid(tips)
y = y.map_diag(plt.hist)
y = y.map_offdiag(plt.scatter)
plt.show()

# %%
sns.PairGrid(tips, hue = 'sex').map_diag(plt.hist).map_offdiag(plt.scatter).add_legend()
plt.show()

# %%
s = sns.PairGrid(iris, hue = 'species', palette = 'husl')
s = s.map_diag(plt.hist,histtype = 'step', linewidth = 3)
s = s.map_offdiag(plt.scatter)
s = s.add_legend()
plt.show()

# %%
sns.violinplot(tips['tip'])
plt.show()

# %%
sns.violinplot(x = 'size', y = 'total_bill',data = tips)
plt.show()

# %%
sns.violinplot(x = 'day', y = 'tip', hue = 'sex', data = tips, palette = 'husl')
plt.show()

# %%
sns.violinplot(x = 'day', y = 'tip', hue = 'sex', data = tips, palette = 'coolwarm', split = True)
plt.show()

# %%
sns.violinplot(x = 'day', y = 'total_bill',hue = 'smoker', data = tips, palette = 'coolwarm', inner = 'quartile', split = True)
plt.show()

# %%
sns.violinplot(x = 'day', y = 'total_bill',hue = 'smoker', data = tips, palette = 'coolwarm', inner = 'quartile', split = True, scale = 'count')
plt.show()

# %%
sns.violinplot(x = 'day', y = 'total_bill',hue = 'smoker', data = tips, palette = 'coolwarm', inner = 'stick', split = True, scale = 'count')
plt.show()

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = tips, color = 'green', kind = 'reg')
plt.show()

# %%
sns.jointplot(x='total_bill', y='tip', data = tips, kind='hex')
plt.show()

# %%
sns.jointplot(x='total_bill', y='tip', data = tips, kind='kde')
plt.show()
